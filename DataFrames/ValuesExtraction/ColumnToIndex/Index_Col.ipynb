# %%
import pandas as pd

filepath='C:\\Users\\Admin\\Downloads\\iplauction2023.csv'
# converting column 'name' into a index_column.
s = pd.read_csv(filepath, index_col='name')
s
# Out:
#                 player_style   nationality  base price (in lacs)  \
# name
# Harshit Rana          Bowler         India                   NaN
# Ekant Sen             Batter         India                  20.0
# Wayne Parnell     Allrounder  South Africa                  75.0
# Shakib Al Hasan   Allrounder    Bangladesh                 150.0
# Joe Root              Batter       England                 100.0
# ...                      ...           ...                   ...
# MS Dhoni           WK-Batter         India                   NaN
# Moeen Ali         Allrounder       England                   NaN
# Ruturaj Gaikwad       Batter         India                   NaN
# Rishabh Pant       WK-Batter         India                   NaN
# Axar Patel        Allrounder         India                   NaN
#
#                  final price (in lacs) franchise    status
# name
# Harshit Rana                      20.0       KKR  RETAINED
# ...
