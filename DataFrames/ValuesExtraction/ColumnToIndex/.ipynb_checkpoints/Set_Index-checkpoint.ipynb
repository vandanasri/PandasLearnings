# %%
import pandas as pd

filepath='C:\\Users\\Admin\\Downloads\\iplauction2023.csv'
df = pd.read_csv(filepath)
df.set_index('name')
# Out:
#                 player_style   nationality  base price (in lacs)  \
# name
# Harshit Rana          Bowler         India                   NaN
# Ekant Sen             Batter         India                  20.0
# Wayne Parnell     Allrounder  South Africa                  75.0
# Shakib Al Hasan   Allrounder    Bangladesh                 150.0
# Joe Root              Batter       England                 100.0
# ...                      ...           ...                   ...
# MS Dhoni           WK-Batter         India                   NaN
# Moeen Ali         Allrounder       England                   NaN
# Ruturaj Gaikwad       Batter         India                   NaN
# Rishabh Pant       WK-Batter         India                   NaN
# Axar Patel        Allrounder         India                   NaN
#
#                  final price (in lacs) franchise    status
# name
# Harshit Rana                      20.0       KKR  RETAINED
# ...

# %%
# Sample DataFrame
data = {
    'A': [1, 2, 3, 4],
    'B': ['a', 'b', 'c', 'c'],
    'C': [5, 6, 7, 8]
}
df = pd.DataFrame(data)

# Setting column 'B' as the index
df_new = df.set_index('B')
df_new
# Out:
#    A  C
# B
# a  1  5
# b  2  6
# c  3  7
# c  4  8

# %%
# Setting columns 'A' and 'B' as the index
df.set_index(['A', 'B'])
# Out:
#      C
# A B
# 1 a  5
# 2 b  6
# 3 c  7
# 4 c  8

# %%
# Setting column 'B' as the index but keeping the original column A
df.set_index('B', drop=False)
# Out:
#    A  B  C
# B
# a  1  a  5
# b  2  b  6
# c  3  c  7
# c  4  c  8

# %%
# Appending column 'B' to the existing index
df.set_index('B', append=True)
# Out:
#      A  C
#   B
# 0 a  1  5
# 1 b  2  6
# 2 c  3  7
# 3 c  4  8

# %%
# Trying to set column 'B' as the index with verify_integrity=True
try:
    df.set_index('B', verify_integrity=True)
except ValueError as e:
    print("Value Error: " ,e)
# Out:
# Value Error:  Index has duplicate keys: Index(['c'], dtype='object', name='B')
